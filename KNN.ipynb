# %% [markdown]
# # K-Nearest Neighbors
#
# An example of the nearest neighbor algorithm application using the well known iris dataset
#
# First we import the dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.datasets import load_iris
iris = load_iris()
n_samples, n_features = iris.data.shape
iris.data.shape
# Out:
# (150, 4)

# %% [markdown]
# Then the algorithm itself

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=7, algorithm = 'brute',distance ='weights')

# %% [markdown]
# In the following we will focus on the first and third columns/features of the dataset

# %%
X = iris.data[:,0:2:1]
y = iris['target']

# %%
# %timeit knn.fit(X,y)
# Out:
# 261 µs ± 97.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# Next we can try to map the predictions by asking the prediction for several points in our features space :

# %%
xx,yy = np.meshgrid(np.linspace(0.0,10.0,301),np.linspace(0.0,10.0,301))
predict = knn.predict(np.c_[xx.ravel(),yy.ravel()])
Z = predict.reshape(np.shape(xx))

# %% [markdown]
# Now Visualizaing the result

# %%
plt.figure(figsize=(7,7))
plt.contourf(xx,yy,Z,3,alpha=0.5)
plt.scatter(X.T[0],X.T[1],c=iris['target'])
plt.xlim(4.0,8.0)
plt.ylim(0.0,8.0)
# Out:
# (0.0, 8.0)
